# %% [markdown]
# ## All ansatze experimental data of FULL VQE RUN
#
# Computation data taken from other files in current directory.

# %%
from numpy import array
import numpy as np
import matplotlib.pyplot as plt

# %%
distances=[0.1, 0.2, 0.5, 0.735, 1.0, 1.5, 2.0, 3.0, 4.0]

# HEA of $H_2$
h2_hea_aer_energies=[-0.7051589254466095, -0.8059544241595064, -1.1290945359940423, -1.2445845498133263, -1.275049003955566, -1.2433695886799212, -1.1891259246621833, -1.1093288969445467, -1.0654551294920436]
h2_hea_aer_iterations=[[array(-0.54898867), array(-0.54898867), array(-0.54898867), array(-0.68040141), array(-0.68040141), array(-0.68040141), array(-0.67747926), array(-0.67747926), array(-0.67747926), array(-0.70515885), array(-0.70515885), array(-0.70515885), array(-0.70515893), array(-0.70515893), array(-0.70515893)], [array(-0.64798172), array(-0.64798171), array(-0.64798172), array(-0.78091117), array(-0.78091117), array(-0.78091117), array(-0.77795534), array(-0.77795534), array(-0.77795534), array(-0.80595435), array(-0.80595435), array(-0.80595435), array(-0.80595442), array(-0.80595442), array(-0.80595442)], [array(-0.96022431), array(-0.96022431), array(-0.96022431), array(-1.10232371), array(-1.1023237), array(-1.10232371), array(-1.09916382), array(-1.09916382), array(-1.09916382), array(-1.12909445), array(-1.12909445), array(-1.12909445), array(-1.12909454), array(-1.12909454), array(-1.12909454)], [array(-1.06365335), array(-1.06365335), array(-1.06365335), array(-1.2159017), array(-1.2159017), array(-1.2159017), array(-1.21251634), array(-1.21251634), array(-1.21251634), array(-1.24458446), array(-1.24458446), array(-1.24458446), array(-1.24458455), array(-1.24458455), array(-1.24458455), array(-1.24458455), array(-1.24458455), array(-1.24458455)], [array(-1.07825842), array(-1.07825842), array(-1.07825842), array(-1.24385199), array(-1.24385199), array(-1.24385199), array(-1.24016977), array(-1.24016977), array(-1.24016977), array(-1.27504891), array(-1.27504891), array(-1.27504891), array(-1.275049), array(-1.275049), array(-1.275049), array(-1.275049), array(-1.275049), array(-1.275049)], [array(-1.01383365), array(-1.01383365), array(-1.01383365), array(-1.20698148), array(-1.20698148), array(-1.20698148), array(-1.20268661), array(-1.20268661), array(-1.20268661), array(-1.24336948), array(-1.24336948), array(-1.24336948), array(-1.24336959), array(-1.24336959), array(-1.24336959), array(-1.24336959), array(-1.24336959), array(-1.24336959)], [array(-0.92998745), array(-0.92998745), array(-0.92998745), array(-1.14804496), array(-1.14804496), array(-1.14804496), array(-1.14319613), array(-1.14319613), array(-1.14319613), array(-1.1891258), array(-1.1891258), array(-1.1891258), array(-1.18912592), array(-1.18912592), array(-1.18912592), array(-1.18912592), array(-1.18912592), array(-1.18912592)], [array(-0.81011735), array(-0.81011735), array(-0.81011735), array(-1.06189519), array(-1.06189518), array(-1.06189519), array(-1.05629656), array(-1.05629656), array(-1.05629656), array(-1.10932875), array(-1.10932875), array(-1.10932875), array(-1.1093289), array(-1.1093289), array(-1.1093289), array(-1.1093289), array(-1.1093289), array(-1.1093289)], [array(-0.74429827), array(-0.74429827), array(-0.74429827), array(-1.01454245), array(-1.01454245), array(-1.01454245), array(-1.00853329), array(-1.00853329), array(-1.00853329), array(-1.06545497), array(-1.06545497), array(-1.06545497), array(-1.06545513), array(-1.06545513), array(-1.06545513), array(-1.06545513), array(-1.06545513), array(-1.06545513)]]
h2_hea_aer_runtimes=[0.017063622013665736, 0.01813441698323004, 0.01635424798587337, 0.0228654470120091, 0.021191929990891367, 0.019627546018455178, 0.020783240004675463, 0.02008101000683382, 0.019564957998227328]
h2_hea_ibm_iterations_0_735=[-1.0412421678047858, -1.046333901573566, -1.0410840727289696, -0.9095089337096324, -0.9091354023910377, -0.9114853961913127, -0.9922459891414311, -0.9921417424597907, -0.9844034923996136, -1.0268341428251713, -1.037273123554538, -1.041203156763274, -1.0559969304495265, -1.0494574154264804, -1.0439641433872937, -1.05186810403178, -1.0484739775503584, -1.0534381555139465, -1.0534873683845691, -1.0494528738939335, -1.0496386755219675, -1.0486601860700575, -1.0520414696288611, -1.0559351678341355, -1.052714902066729, -1.0541021497722887, -1.0480200526797474, -1.048654207700061, -1.0535294170161666, -1.0521730026650182, -1.051777348736318, -1.0608939482030137, -1.047973430008839]
# h2_hea_ibm_iteration_runtimes = 13s all

# UCCSD of $H_2$
h2_uccsd_aer_energies=[-2.581811338332701, -2.4884039198016166, -2.113514216310601, -1.857275030202349, -1.6303275411525613, -1.3509341607512477, -1.2132297176356228, -1.1100242481589517, -1.0654656645440537]
h2_uccsd_aer_iterations=[[array(-2.57588472), array(-2.57588472), array(-2.57588472), array(-2.57588471), array(0.19176695), array(0.19176695), array(0.19176695), array(0.19176691), array(-2.58163752), array(-2.58163752), array(-2.58163752), array(-2.58163752), array(-2.58181134), array(-2.58181134), array(-2.58181134), array(-2.58181134), array(-2.58181134), array(-2.58181134), array(-2.58181134), array(-2.58181134)], [array(-2.48171104), array(-2.48171104), array(-2.48171104), array(-2.48171104), array(0.01006155), array(0.01006155), array(0.01006155), array(0.01006152), array(-2.48820939), array(-2.48820939), array(-2.48820939), array(-2.48820939), array(-2.48840392), array(-2.48840392), array(-2.48840392), array(-2.48840392), array(-2.48840392), array(-2.48840392), array(-2.48840392), array(-2.48840392)], [array(-2.1013507), array(-2.1013507), array(-2.1013507), array(-2.10135069), array(-0.60345123), array(-0.60345123), array(-0.60345123), array(-0.60345125), array(-2.11318414), array(-2.11318414), array(-2.11318414), array(-2.11318414), array(-2.11351421), array(-2.11351421), array(-2.11351421), array(-2.11351421), array(-2.11351422), array(-2.11351422), array(-2.11351422), array(-2.11351422)], [array(-1.83696799), array(-1.83696799), array(-1.83696799), array(-1.83696799), array(-0.87441261), array(-0.87441261), array(-0.87441261), array(-0.87441263), array(-1.85678494), array(-1.85678494), array(-1.85678494), array(-1.85678494), array(-1.85727498), array(-1.85727498), array(-1.85727498), array(-1.85727498), array(-1.85727503), array(-1.85727503), array(-1.85727503), array(-1.85727503)], [array(-1.59528586), array(-1.59528586), array(-1.59528586), array(-1.59528586), array(-1.01650733), array(-1.01650733), array(-1.01650733), array(-1.01650734), array(-1.62967613), array(-1.62967613), array(-1.62967613), array(-1.62967613), array(-1.63032717), array(-1.63032717), array(-1.63032717), array(-1.63032717), array(-1.63032754), array(-1.63032754), array(-1.63032754), array(-1.63032754)], [array(-1.26365836), array(-1.26365836), array(-1.26365836), array(-1.26365836), array(-1.10672197), array(-1.10672197), array(-1.10672197), array(-1.10672197), array(-1.3506266), array(-1.3506266), array(-1.3506266), array(-1.3506266), array(-1.3509311), array(-1.3509311), array(-1.3509311), array(-1.3509311), array(-1.35093416), array(-1.35093416), array(-1.35093416), array(-1.35093416)], [array(-1.04838126), array(-1.04838126), array(-1.04838126), array(-1.04838125), array(-1.11229888), array(-1.11229888), array(-1.11229888), array(-1.11229889), array(-1.21291185), array(-1.21291185), array(-1.21291185), array(-1.21291185), array(-1.21322444), array(-1.21322444), array(-1.21322444), array(-1.21322444), array(-1.21322972), array(-1.21322972), array(-1.21322972), array(-1.21322972)], [array(-0.83244065), array(-0.83244065), array(-0.83244065), array(-0.83244065), array(-1.07269138), array(-1.07269138), array(-1.07269138), array(-1.07269139), array(-1.10672085), array(-1.10672085), array(-1.10672085), array(-1.10672085), array(-1.11002117), array(-1.11002117), array(-1.11002117), array(-1.11002117), array(-1.11002425), array(-1.11002425), array(-1.11002425), array(-1.11002425)], [array(-0.74716428), array(-0.74716428), array(-0.74716428), array(-0.74716427), array(-1.03512948), array(-1.03512948), array(-1.03512948), array(-1.03512948), array(-1.06148357), array(-1.06148357), array(-1.06148357), array(-1.06148357), array(-1.06546394), array(-1.06546394), array(-1.06546394), array(-1.06546394), array(-1.06546566), array(-1.06546566), array(-1.06546566), array(-1.06546566)]]
h2_uccsd_aer_runtimes=[0.12952407699776813, 0.1197768050187733, 0.11400804898585193, 0.12197749098413624, 0.11859144299523905, 0.12908469900139607, 0.11893639198387973, 0.11636234397883527, 0.11750166999991052]
h2_fci_energies=[np.float64(2.709960770867275), np.float64(0.1574821347983626), np.float64(-1.0551597944706266), np.float64(-1.1373060357534004), np.float64(-1.1011503302326187), np.float64(-0.9981493534714101), np.float64(-0.9486411121761855), np.float64(-0.9336318445584986), np.float64(-0.9331713618436487)]
h2_fci_runtimes=[0.10744974497356452, 0.09115458000451326, 0.057471139007247984, 0.08491390399285592, 0.035672687023179606, 0.056222457002149895, 0.054380237008444965, 0.047080445976462215, 0.04863502498483285]

# UCCSD of $LiH$
lih_uccsd_aer_distances=[0.1, 0.2, 0.5, 0.735, 1.0, 1.5, 2.0]
lih_uccsd_aer_energies=[-13.112363287270423, -11.979295472686722, -9.965183119853345, -9.61857520311112, -9.371986722349414, -8.877708929024562, -8.654834873588358]
lih_uccsd_aer_iterations=[]
lih_uccsd_aer_runtimes=[6858.5413069149945, 5695.017285942013, 6388.339810810023, 2095.3139717669983, 6081.105023662996, 1747.4163400109974, 1764.0681546150008]
lih_fci_energies=[np.float64(2.762907536704784), np.float64(-4.041729925672344), np.float64(-7.319318937542141), np.float64(-7.634167329324351), np.float64(-7.784460280031234), np.float64(-7.8824019322902314), np.float64(-7.861087772481499), np.float64(-7.7988431595024075), np.float64(-7.784278178715387)]
lih_fci_runtimes=[0.9482909129874315, 1.0932603630062658, 1.070728668011725, 1.0170216239930596, 1.411874743993394, 0.9020845769846346, 1.1578565800155047, 0.8331611010071356, 1.203765828977339]

# UCCSD of $BeH_2$
beh2_uccsd_aer_iterations=[[array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725958), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725958), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725958), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725958), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725958), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725958), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725959), array(-31.48725958), array(-31.48725959), array(-31.48725959), array(-31.48725959)], [], [], [], [], [], [], [], []]

# ADAPT-VQE of $H_2$
h2_adapt_aer_energies=[np.float64(-2.5818113383327237), np.float64(-2.488403919801636), np.float64(-2.113514216310623), np.float64(-1.8572750302023782), np.float64(-1.630327541152571), np.float64(-1.3509341607511838), np.float64(-1.2132297176356395), np.float64(-1.1100242481593074), np.float64(-1.0654656645451264)]
h2_adapt_aer_numiters=[2, 2, 2, 2, 2, 2, 2, 2, 2]
h2_adapt_aer_runtimes=[0.03821393000544049, 0.05099697699188255, 0.03937136000604369, 0.06124262700905092, 0.060679895017528906, 0.04848977201618254, 0.06398243102012202, 0.0402004599745851, 0.03336154800490476]

# ADAPT-VQE of $LiH$
lih_adapt_aer_energies=[np.float64(-0.9575002517408583), np.float64(-0.9279088894659918), np.float64(-0.9874449054942488), np.float64(-1.1258855800620267), np.float64(-1.1742345538695922), np.float64(-1.1001795361250646), np.float64(-0.9904135795826925), np.float64(-0.8396276373175492), np.float64(-0.780846410388818)]
lih_adapt_aer_numiters=[11, 11, 11, 9, 9, 10, 11, 11, 8]
lih_adapt_aer_runtimes=[41.95097169899964, 54.755986183998175, 47.73227245200542, 34.52891978799016, 31.71293575601885, 38.05666062099044, 44.26272849799716, 54.33006294298684, 27.969268604007084]

# ADAPT-VQE of $BeH_2$
beh2_adapt_aer_energies=[np.float64(-5.142260481477643), np.float64(-5.193126813213986), np.float64(-5.026473131657737), np.float64(-4.791074703779565), np.float64(-4.423492232342608), np.float64(-3.7230335955303), np.float64(-3.1948979038149927), np.float64(-2.6905354551867613), np.float64(-2.492092432599376)]
beh2_adapt_aer_numiters=[17, 16, 19, 17, 17, 17, 20, 27, 10]
beh2_adapt_aer_runtimes=[79.01601827002014, 71.72644568700343, 99.23219260497717, 85.53832248799154, 84.55502803099807, 82.94143104899558, 196.82583333199727, 745.5838248670043, 26.684036922000814]

# 1-UpCCGSD of $H_2$
h2_up1_madness_energies=[2.5068411362813094, 0.03150418518107145, -1.0775624754318152, -1.1515354278241712, -1.1284779543043908, -1.0535782089265744, -1.007246673096429, -0.9807003897856368, -0.9789631658988838]
h2_up1_madness_runtimes=[25.291087851015618, 24.42004117698525, 21.787617133988533, 21.57766136000282, 19.053073054004926, 19.529676006990485, 20.035764607979218, 22.877647863992024, 23.999218034005025]
h2_up1_madness_numiters=[2, 5, 2, 2, 3, 3, 4, 3, 4]

# 2-UpCCGSD of $H_2$
# Took too long to run
# After 1 hour it was still running, not one calculation done, exact details unknown
h2_up2_madness_energies=[]
h2_up2_madness_runtimes=[]
h2_up2_madness_numiters=[]

# 1-UpCCGSD of $LiH$
lih_up1_madness_energies=[2.2588859015578016, -4.442963155211035, -7.2186245866055945, -7.6900673781414435, -7.904030559448709, -8.000624077256733, -7.993192086096469, -7.946692077027988, -7.91490464429416]
lih_up1_madness_runtimes=[29.359438102000013, 29.317981073000055, 33.07312523799999, 30.31769078100001, 23.788237872999957, 27.881071223000163, 24.43731880700011, 29.95807144000014, 35.67778201400006]
lih_up1_madness_numiters=[3, 4, 3, 2, 2, 3, 3, 4, 6]

# 2-UpCCGSD of $LiH$
lih_up2_madness_energies=[]
lih_up2_madness_runtimes=[]
lih_up2_madness_numiters=[]

# 1-UpCCGSD of $BeH_2$
beh2_up1_madness_energies=[12.675585864291742, -5.66893621414981, -14.011468396637692, -15.248289078923827, -15.688899320110941, -15.787877471063325, -15.696242227441056, -15.536931389205096, -15.420397512346284]
beh2_up1_madness_runtimes=[64.83134163699992, 67.84321374199999, 59.90171977499995, 82.582360655, 68.95003232099998, 76.88548920200014, 84.16073558500011, 108.12260334999996, 141.82318519499995]
beh2_up1_madness_numiters=[2, 3, 3, 4, 3, 3, 4, 6, 8]

# 2-UpCCGSD of $BeH_2$
beh2_up2_madness_energies=[]
beh2_up2_madness_runtimes=[]
beh2_up2_madness_numiters=[]

# FCI BeH2
beh2_fci_energies=[np.float64(13.441502018292972), np.float64(-5.266247480067964), np.float64(-13.689960305740966), np.float64(-14.871329754970802), np.float64(-15.481741069507603), np.float64(-15.595117562572968), np.float64(-15.446093740443274), np.float64(-15.336804236060548), np.float64(-15.336821512483452)]
beh2_fci_runtimes=[0.4010506490000125, 0.25499150400003145, 0.4116107600000305, 0.9549862300000314, 0.24008450299993456, 0.26117932500005736, 0.2510901590000003, 0.2503979220000474, 0.2828930150000133]

# %% [markdown]
# # $H_2$

# %%
plt.plot(distances, h2_uccsd_aer_energies, 'x-', label='UCCSD')
plt.plot(distances, h2_fci_energies, 'o-', label='FCI')
plt.plot(distances, h2_adapt_aer_energies, 'o-', label='ADAPT-VQE')
plt.plot(distances, h2_up1_madness_energies, 'o-', label='1-UpCCGSD')
plt.plot(distances, h2_hea_aer_energies, 'o-', label='HEA')
plt.legend()
plt.xlabel('Distance ($\\AA$)')
plt.ylabel('Energy (Hartree)')
plt.title('$H_2$ ground state energy')
plt.show()

# %%
plt.plot(distances, h2_uccsd_aer_runtimes, 'x-', label='UCCSD')
plt.plot(distances, h2_fci_runtimes, 'o-', label='FCI')
plt.plot(distances, h2_adapt_aer_runtimes, 'o-', label='ADAPT-VQE')
plt.plot(distances, h2_up1_madness_runtimes, 'o-', label='1-UpCCGSD')
plt.plot(distances, h2_hea_aer_runtimes, 'o-', label='HEA')
plt.legend()
plt.xlabel('Distance ($\\AA$)')
plt.ylabel('Time (s)')
plt.title('$H_2$ runtime')
plt.show()

# %%
plt.plot(distances, [len(row) for row in h2_uccsd_aer_iterations], 'x-', label='UCCSD')
plt.plot(distances, h2_adapt_aer_numiters, 'o-', label='ADAPT-VQE')
plt.plot(distances, h2_up1_madness_numiters, 'o-', label='1-UpCCGSD')
plt.plot(distances, [len(row) for row in h2_hea_aer_iterations], 'o-', label='HEA')
plt.legend()
plt.xlabel('Distance ($\\AA$)')
plt.ylabel('Iterations')
plt.title('$H_2$ iterations')
plt.show()

# %%
plt.plot(distances, [abs(e - f) for e, f in zip(h2_uccsd_aer_energies, h2_fci_energies)], marker='x', linestyle='-', label="|UCCSD - FCI|")
plt.plot(distances, [abs(e - f) for e, f in zip(h2_adapt_aer_energies, h2_fci_energies)], marker='+', linestyle='-', label="|ADAPT-VQE - FCI|")
plt.plot(distances, [abs(e - f) for e, f in zip(h2_up1_madness_energies, h2_fci_energies)], marker='o', linestyle='-', label="|1-UpCCGSD - FCI|")
plt.plot(distances, [abs(e - f) for e, f in zip(h2_hea_aer_energies, h2_fci_energies)], marker='*', linestyle='-', label="|HEA - FCI|")
plt.legend()
plt.xlabel('Distance ($\\AA$)')
plt.ylabel('Energy difference (Hartree)')
plt.title('$H_2$ computation error')
plt.show()

# %% [markdown]
# ## $H_2$ example with convergence

# %%
plt.plot(h2_uccsd_aer_iterations[3], 'x-', label='UCCSD, Aer')
plt.plot(h2_hea_ibm_iterations_0_735, 'o-', label='HEA, ibm_brisbane')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Energy (Hartree)')
plt.title('$H_2$ energy convergence, 0.735 $\\AA$')
plt.show()

# %% [markdown]
# ## $LiH$

# %%
plt.plot(lih_uccsd_aer_distances, lih_uccsd_aer_energies, 'o-', label='UCCSD')
plt.plot(distances, lih_adapt_aer_energies, 'o-', label='ADAPT-VQE')
plt.plot(distances, lih_up1_madness_energies, 'o-', label='1-UpCCGSD')
plt.plot(distances, lih_fci_energies, 'o-', label='FCI')

plt.legend()
plt.xlabel('Distance ($\\AA$)')
plt.ylabel('Energy (Hartree)')
plt.title('$LiH$ ground state energy')
plt.show()

# %%
plt.plot(lih_uccsd_aer_distances, [abs(e - f) for e, f in zip(lih_uccsd_aer_energies, lih_fci_energies)], marker='x', linestyle='-', label="|UCCSD - FCI|")
plt.plot(distances, [abs(e - f) for e, f in zip(lih_adapt_aer_energies, lih_fci_energies)], marker='+', linestyle='-', label="|ADAPT-VQE - FCI|")
plt.plot(distances, [abs(e - f) for e, f in zip(lih_up1_madness_energies, lih_fci_energies)], marker='o', linestyle='-', label="|1-UpCCGSD - FCI|")
plt.legend()
plt.xlabel('Distance ($\\AA$)')
plt.ylabel('Energy difference (Hartree)')
plt.title('$LiH$ computation error')
plt.show()

# %%
plt.plot(lih_uccsd_aer_distances, lih_uccsd_aer_runtimes, 'x-', label='UCCSD')
plt.plot(distances, lih_adapt_aer_runtimes, 'o-', label='ADAPT-VQE')
plt.plot(distances, lih_up1_madness_runtimes, 'o-', label='1-UpCCGSD')
plt.plot(distances, lih_fci_runtimes, 'o-', label='FCI')
plt.legend()
plt.xlabel('Distance ($\\AA$)')
plt.ylabel('Time (s)')
plt.title('$LiH$ runtime')
plt.show()

# %%
plt.plot(lih_uccsd_aer_distances, lih_uccsd_aer_iterations, 'x-', label='UCCSD')
plt.plot(distances, lih_adapt_aer_numiters, 'o-', label='ADAPT-VQE')
plt.plot(distances, lih_up1_madness_numiters, 'o-', label='1-UpCCGSD')
plt.legend()
plt.xlabel('Distance ($\\AA$)')
plt.ylabel('Iterations')
plt.title('$LiH$ iterations')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 plt.plot(lih_uccsd_aer_distances, lih_uccsd_aer_iterations, 'x-', label='UCCSD')
#       2 plt.plot(distances, lih_adapt_aer_numiters, 'o-', label='ADAPT-VQE')
#       3 plt.plot(distances, lih_up1_madness_numiters, 'o-', label='1-UpCCGSD')
#
# File ~/Desktop/PLAYGROUND/vqe-analysis-paper/qiskit-env/lib/python3.13/site-packages/matplotlib/pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
# ...

# %% [markdown]
# ## $BeH_2$

# %%
plt.plot(distances, beh2_adapt_aer_energies, 'x-', label='ADAPT-VQE')
plt.plot(distances, beh2_up1_madness_energies, 'o-', label='1-UpCCGSD')
plt.plot(distances, beh2_fci_energies, 'o-', label='FCI')
plt.legend()
plt.xlabel('Distance ($\\AA$)')
plt.ylabel('Energy (Hartree)')
plt.title('$BeH_2$ ground state energy')
plt.show()

# %%
plt.plot(distances, beh2_adapt_aer_runtimes, 'x-', label='ADAPT-VQE')
plt.plot(distances, beh2_up1_madness_runtimes, 'o-', label='1-UpCCGSD')
plt.plot(distances, beh2_fci_runtimes, 'o-', label='FCI')
plt.legend()
plt.xlabel('Distance ($\\AA$)')
plt.ylabel('Time (s)')
plt.title('$BeH_2$ runtime')
plt.show()

# %%
plt.plot(distances, beh2_adapt_aer_numiters, 'x-', label='ADAPT-VQE')
plt.plot(distances, beh2_up1_madness_numiters, 'o-', label='1-UpCCGSD')
plt.legend()
plt.xlabel('Distance ($\\AA$)')
plt.ylabel('Iterations')
plt.title('$BeH_2$ iterations')
plt.show()

# %%
plt.plot(distances, [abs(e - f) for e, f in zip(beh2_up1_madness_energies, lih_fci_energies)], marker='o', linestyle='-', label="|1-UpCCGSD - FCI|")
plt.plot(distances, [abs(e - f) for e, f in zip(beh2_adapt_aer_energies, lih_fci_energies)], marker='x', linestyle='-', label="|ADAPT-VQE - FCI|")
plt.legend()
plt.xlabel('Distance ($\\AA$)')
plt.ylabel('Energy difference (Hartree)')
plt.title('$BeH_2$ computation error')
plt.show()
