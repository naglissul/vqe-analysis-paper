# %% [markdown]
#     \item circuit depth,
#     \item parameter count,
#     \item TRAINABILITY,
#     \item EXPRESSIBILITY.

# %%
# HEA of $H_2$
h2_hea_circuit_depth = 2
h2_hea_parameter_count = 2
h2_hea_trainability = ...
h2_hea_expressibility = ...

# UCCSD of $H_2$
h2_uccsd_circuit_depth = 4
h2_uccsd_parameter_count = 4
h2_uccsd_trainability = ...
h2_uccsd_expressibility = ...

# UCCSD of $LiH$
lih_uccsd_circuit_depth = 4
lih_uccsd_parameter_count = 4
lih_uccsd_trainability = ...
lih_uccsd_expressibility = ...

# UCCSD of $BeH_2$
be2_uccsd_circuit_depth = 4
be2_uccsd_parameter_count = 4
be2_uccsd_trainability = ...
be2_uccsd_expressibility = ...

# 1-UpCCGSD of $H_2$
h2_1upccgsd_circuit_depth = 4
h2_1upccgsd_parameter_count = 4
h2_1upccgsd_trainability = ...
h2_1upccgsd_expressibility = ...

# 2-UpCCGSD of $H_2$
h2_2upccgsd_circuit_depth = 4
h2_2upccgsd_parameter_count = 4
h2_2upccgsd_trainability = ...
h2_2upccgsd_expressibility = ...

# 1-UpCCGSD of $LiH$
lih_1upccgsd_circuit_depth = 4
lih_1upccgsd_parameter_count = 4
lih_1upccgsd_trainability = ...
lih_1upccgsd_expressibility = ...

# 2-UpCCGSD of $LiH$
lih_2upccgsd_circuit_depth = 4
lih_2upccgsd_parameter_count = 4
lih_2upccgsd_trainability = ...
lih_2upccgsd_expressibility = ...

# 1-UpCCGSD of $BeH_2$
be2_1upccgsd_circuit_depth = 4
be2_1upccgsd_parameter_count = 4
be2_1upccgsd_trainability = ...
be2_1upccgsd_expressibility = ...

# 2-UpCCGSD of $BeH_2$
be2_2upccgsd_circuit_depth = 4
be2_2upccgsd_parameter_count = 4
be2_2upccgsd_trainability = ...
be2_2upccgsd_expressibility = ...
